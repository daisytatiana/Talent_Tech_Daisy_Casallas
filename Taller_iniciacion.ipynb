# %% [markdown]
# <a href="https://colab.research.google.com/github/daisytatiana/EjercicioAnalisis/blob/main/Taller_iniciacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importacion de la libreria pandas para el manejo de datos
import pandas as pd

# %%
df_1= pd.read_csv("/content/set1.csv",delimiter=";")

# %%
df_1.head()
# Out:
#     id weight height   age gender       Unnamed: 5                 Unnamed: 6
# 0  1.0  144,5    5,9  33.0      M              NaN                        NaN
# 1  2.0  167,2    5,4  45.0      M     TIPO DE DATO  Decimales, enteros, texto
# 2  3.0  124,1    5,2  23.0      F         CANTIDAD                         45
# 3  4.0  144,5    5,9  33.0      M  CARACTERISTICAS         Id sin consecutivo
# 4  5.0  133,2    5,7  54.0      F         PATRONES                        NaN

# %%
df_2=df_1
