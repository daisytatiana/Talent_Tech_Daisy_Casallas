# %% [markdown]
# <a href="https://colab.research.google.com/github/daisytatiana/EjercicioAnalisis/blob/main/Taller_iniciacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importacion de la libreria pandas para el manejo de datos
import pandas as pd

# %%
#llamado a la funcion read para la lectura del archivo csv
df_1= pd.read_csv("/content/set1.csv",delimiter=";")

# %%
#Muestra los datos contenidos del archivo csv
df_1.head()
# Out:
#     id weight height   age gender       Unnamed: 5                 Unnamed: 6
# 0  1.0  144,5    5,9  33.0      M              NaN                        NaN
# 1  2.0  167,2    5,4  45.0      M     TIPO DE DATO  Decimales, enteros, texto
# 2  3.0  124,1    5,2  23.0      F         CANTIDAD                         45
# 3  4.0  144,5    5,9  33.0      M  CARACTERISTICAS         Id sin consecutivo
# 4  5.0  133,2    5,7  54.0      F         PATRONES                        NaN

# %%
#Guarda los archivos del df 1 en el df 2
df_2=df_1

# %%
#llamado de la funcion read para la lectura del archivo excel
df_3=pd.read_excel("/content/example_ventas.xlsx")

# %%
#mostrar datos del df3
df_3
# Out:
#         Fecha   Region      Producto Vendedor  Ventas
# 0  2024-01-31  Central    Accesorios    David    8287
# 1  2024-02-01  Central    Accesorios    Karen    6909
# 2  2024-02-02  Central  Dispositivos    David   11420
# 3  2024-02-03  Central  Dispositivos    Karen   12948
# 4  2024-02-04  Central      Sistemas    David   20098
# 5  2024-02-05  Central      Sistemas    Karen   30633
# 6  2024-02-06     Este    Accesorios      Ana    9323
# 7  2024-02-07     Este    Accesorios    Lucas    7667
# 8  2024-02-08     Este  Dispositivos      Ana   10348
# 9  2024-02-09     Este  Dispositivos    Lucas    9312
# 10 2024-02-10     Este      Sistemas      Ana   13531
# 11 2024-02-11     Este      Sistemas    Lucas   13374
# 12 2024-02-12    Oeste    Accesorios    Kevin    4744
# 13 2024-02-13    Oeste    Accesorios     Sara    5442
# 14 2024-02-14    Oeste  Dispositivos    Kevin   10711
# 15 2024-02-15    Oeste  Dispositivos     Sara    8780
# ...
